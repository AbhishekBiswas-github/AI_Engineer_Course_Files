# %% [markdown]
# # Python Variables

# %% [markdown]
# ## Exercise 1

# %%
## Exercise 1
x = 10
x

## Exercise 2
x = 10
print(x)

## Exercise 3
a, b, c, d = (10, 20, 30, 40)

## Exercise 4
a, b, c, d = (10, 20, 30, 40)
print(b)
print(d)
# Out:
# 10
# 20
# 40

# %% [markdown]
# # Python Numbers and Booleans

# %%
## Exercise 1
a = True
type(a)

## Exercise 2
b = 99
type(b)

## Exercise 3
type(0.99)

## Exercise 4
b = 99
b = float(b)
print(b)

## Exercise 5
int(0.99)
# Out:
# 99.0
# 0

# %% [markdown]
# # Python Strings

# %%
## Exercise 1
m = 100
print(100, 'days')

## Exercise 2
print('It\'s cool, isn\'t it?')

## Exercise 3
print('Don\'t be shy')

## Exercise 4
print('Click "OK"')

## Exercise 5
print('Big', 'Houses')
# Out:
# 100 days
# It's cool, isn't it?
# Don't be shy
# Click "OK"
# Big Houses
