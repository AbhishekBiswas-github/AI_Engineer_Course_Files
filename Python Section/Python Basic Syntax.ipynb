# %% [markdown]
# # Arithmetic Operators

# %%
# Exercise 1
15 + 23

# Exercise 2
26 - 50

# Exercise 3
20 / 4

# Exercise 4
22 / 4

# Exercise 5
22 % 4

# Exercise 6
22.0 / 4

# Exercise 7
6 * 8

# Exercise 8
15 ** 2
# Out:
# 225

# %% [markdown]
# #  The Double Equality Sign

# %%
# Exercise 1
100 == 98
# Out:
# False

# %% [markdown]
# # Reassign Values

# %%
# Exercise 1
p = 14

# Exercise 2
p + 10

# Exercise 3
p = 30

# Exercise 4
p + 10
# Out:
# 40

# %% [markdown]
# # Indexing

# %%
# Exercise 1
'Bingo!'[0]

# Exercise 2
'Constitution'[7]
# Out:
# 'u'
