# %% [markdown]
# # Comparison Operators

# %%
# Exercise 1
25 < 30

# Exercise 2
5*3 <= 5**3

# Exercise 3
100 == 10**2

# Exercise 4
53 != 46
# Out:
# True

# %% [markdown]
# # Logical and Identity Operators

# %%
# Exercise 1
False or not True and not False

# Exercise 2
True and not False and True or not False

# Exercise 3
True or False and False

# Exercise 4
False and True or False

# Exercise 5
10 is not 12

# Exercise 6
50 is 50
# Out:
# <>:14: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:17: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:14: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:17: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\1852267\AppData\Local\Temp\ipykernel_10868\3510381249.py:14: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   10 is not 12
# C:\Users\1852267\AppData\Local\Temp\ipykernel_10868\3510381249.py:17: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   50 is 50
# True
