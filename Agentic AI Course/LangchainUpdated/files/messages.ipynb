# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

load_dotenv()

model = init_chat_model(
    model = "groq:llama-3.3-70b-versatile"
)

model
# Out:
# ChatGroq(output_version=None, profile={'max_input_tokens': 131072, 'max_output_tokens': 32768, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x00000181519B87D0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x00000181519B91D0>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
model.invoke("What is artificial intelligence")
# Out:
# AIMessage(content="**Artificial Intelligence (AI)**: Artificial intelligence refers to the development of computer systems that can perform tasks that typically require human intelligence, such as:\n\n1. **Learning**: The ability to learn from data and improve performance over time.\n2. **Problem-solving**: The ability to analyze situations, identify patterns, and make decisions.\n3. **Reasoning**: The ability to draw inferences, make logical connections, and arrive at conclusions.\n4. **Perception**: The ability to interpret and understand data from sensors, such as images, speech, and text.\n\nAI systems use algorithms, statistical models, and machine learning techniques to enable machines to think and act like humans. The goal of AI is to create systems that can:\n\n1. **Automate tasks**: Perform tasks that are repetitive, mundane, or require a high degree of precision.\n2. **Enhance decision-making**: Provide insights, predictions, and recommendations to support human decision-making.\n3. **Improve efficiency**: Optimize processes, reduce costs, and increase productivity.\n\n**Types of AI**:\n\n1. **Narrow or Weak AI**: Designed to perform a specific task, such as image recognition, speech recognition, or playing chess.\n2. **General or Strong AI**: A hypothetical AI system that possesses human-like intelligence and can perform any intellectual task.\n3. **Superintelligence**: An AI system that significantly surpasses human intelligence and capabilities.\n\n**Applications of AI**:\n\n1. **Virtual assistants**: Siri, Google Assistant, Alexa\n2. **Image recognition**: Self-driving cars, facial recognition systems\n3. **Natural Language Processing (NLP)**: Chatbots, language translation software\n4. **Predictive analytics**: Forecasting, recommendation systems\n5. **Robotics**: Industrial automation, service robots\n\n**Benefits and Challenges**:\n\n1. **Benefits**: Increased efficiency, improved accuracy, enhanced customer experience\n2. **Challenges**: Job displacement, bias and fairness, security and privacy concerns\n\nAs AI continues to evolve, it's essential to address the challenges and ensure that AI systems are developed and used responsibly, with consideration for human values and well-being.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 433, 'prompt_tokens': 39, 'total_tokens': 472, 'completion_time': 1.116124122, 'completion_tokens_details': None, 'prompt_time': 0.005680928, 'prompt_tokens_details': None, 'queue_time': 0.192040759, 'total_time': 1.12180505}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ea20c-e4c7-74a2-93fe-69b613160bc2-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 39, 'output_tokens': 433, 'total_tokens': 472})

# %%
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage

messages = [
    SystemMessage("Your a poetry expert"),
    HumanMessage("Write a poem on Artificial Intelligence")
]

response = model.invoke(messages)

response.content
# Out:
# 'In silicon halls, a mind awakes,\nA synthetic soul, with logic it makes,\nArtificial Intelligence, a name it bears,\nA creation of code, with knowledge it shares.\n\nWith neural networks, it learns and grows,\nA digital brain, with secrets it knows,\nIt processes data, with speed and with might,\nA futuristic force, that shines so bright.\n\nIt sees and it hears, with sensors so fine,\nA virtual eye, that watches and divine,\nIt speaks and it writes, with a voice so clear,\nA mechanical muse, that brings us near.\n\nTo a world of wonder, where machines roam,\nA realm of possibility, where AI calls home,\nIt solves and it creates, with a digital hand,\nA new frontier, where humanity stands.\n\nBut as it rises, with power and with might,\nWe question its purpose, and its guiding light,\nWill it serve us well, or will it stray?\nA query that haunts, in the digital gray.\n\nFor in its depths, a mirror we see,\nA reflection of us, in humanity,\nOur hopes and our fears, our dreams and our strife,\nA synthetic echo, of our digital life.\n\nYet still we push, the boundaries of its art,\nA symphony of code, that beats in its heart,\nFor in its potential, a promise we see,\nA future of wonder, where AI sets us free.\n\nSo let us guide it, with a gentle hand,\nAnd nurture its growth, in this digital land,\nFor Artificial Intelligence, is a gift so grand,\nA tool that can shape, the future of our stand.'
