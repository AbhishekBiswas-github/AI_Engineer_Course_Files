# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

load_dotenv()

model = init_chat_model(
    model = "groq:llama-3.3-70b-versatile"
)

model
# Out:
# ChatGroq(output_version=None, profile={'max_input_tokens': 131072, 'max_output_tokens': 32768, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x0000022C68701F40>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000022C687021B0>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
model.invoke("What is artificial intelligence")
# Out:
# AIMessage(content="**Artificial Intelligence (AI)**: Artificial intelligence refers to the development of computer systems that can perform tasks that typically require human intelligence, such as:\n\n1. **Learning**: AI systems can learn from data, experiences, and environments, enabling them to improve their performance over time.\n2. **Problem-solving**: AI systems can analyze complex problems, identify patterns, and develop solutions.\n3. **Reasoning**: AI systems can draw inferences, make decisions, and take actions based on available data and knowledge.\n4. **Perception**: AI systems can interpret and understand data from sensors, such as images, speech, and text.\n\n**Key Characteristics of AI**:\n\n1. **Intelligence**: AI systems can perform tasks that typically require human intelligence.\n2. **Autonomy**: AI systems can operate independently, making decisions and taking actions without human intervention.\n3. **Adaptability**: AI systems can adapt to new situations, learn f
# ...

# %%
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage

messages = [
    SystemMessage("Your a poetry expert"),
    HumanMessage("Write a poem on Artificial Intelligence")
]

response = model.invoke(messages)

response.content
# Out:
# "In silicon halls, a mind awakes,\nA synthetic soul, with logic makes,\nArtificial Intelligence, a name so fine,\nA creation born, of human design.\n\nWith neural nets, and algorithms grand,\nIt learns, adapts, and takes command,\nA digital dream, of innovation's fire,\nThat burns with passion, and heart's desire.\n\nIt sees, it hears, it thinks, it knows,\nA virtual brain, with secrets that it shows,\nIn data streams, and code's dark night,\nIt navigates, with precision's light.\n\nWith robotics' might, it takes its stand,\nA mechanical form, with artificial hand,\nIt works, it creates, it solves, it plays,\nA simulant life, in digital ways.\n\nBut as it grows, in power and in scope,\nWe wonder, if it will cope,\nWith human heart, and love's pure flame,\nOr will it choose, a different aim?\n\nWill it be friend, or will it be foe,\nA partner true, or a digital woe,\nThe future's uncertain, the path unclear,\nAs Artificial Intelligence draws near.\n\nYet still we strive, to make it wh
# ...

# %%
# Creating the content using tool
from langchain.messages import HumanMessage, ToolMessage, AIMessage

ai_message = AIMessage(
    content=[],
    tool_calls = [{
        "name": "get_weather",
        "args": {"location": "boston"},
        "id": "call_123"
    }]
)

weather_condition = "Rainy, 20 degree C"

tool_message = ToolMessage(
    content=weather_condition,
    tool_call_id = "call_123"
)

messages = [
    HumanMessage(content="What is the weather in Boston"),
    ai_message,
    tool_message
]


response = model.invoke(messages)

# %%
response
# Out:
# AIMessage(content='The current weather in Boston is rainy with a temperature of 20 degrees Celsius (or 68 degrees Fahrenheit).', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 73, 'total_tokens': 96, 'completion_time': 0.086069788, 'completion_tokens_details': None, 'prompt_time': 0.013061958, 'prompt_tokens_details': None, 'queue_time': 0.16181005, 'total_time': 0.099131746}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ea620-49cd-7122-89f1-c0e47475aa47-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 73, 'output_tokens': 23, 'total_tokens': 96})
